# %% [markdown]
# FOR 3 SECONDS, SAMPLING RATE = 6000

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data science and mathematical operations
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.io import wavfile
import librosa
import IPython
import IPython.display as ipd

from keras.layers import Dense, Dropout, Input, ReLU
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras import models

import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/genres_original'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/genres_original/country/country.00046.wav
# /content/drive/MyDrive/genres_original/country/country.00053.wav
# /content/drive/MyDrive/genres_original/country/country.00062.wav
# /content/drive/MyDrive/genres_original/country/country.00054.wav
# /content/drive/MyDrive/genres_original/country/country.00051.wav
# /content/drive/MyDrive/genres_original/country/country.00055.wav
# /content/drive/MyDrive/genres_original/country/country.00056.wav
# /content/drive/MyDrive/genres_original/country/country.00049.wav
# /content/drive/MyDrive/genres_original/country/country.00047.wav
# /content/drive/MyDrive/genres_original/country/country.00059.wav
# /content/drive/MyDrive/genres_original/country/country.00048.wav
# /content/drive/MyDrive/genres_original/country/country.00058.wav
# /content/drive/MyDrive/genres_original/country/country.00061.wav
# /content/drive/MyDrive/genres_original/country/country.00052.wav
# /content/drive/MyDrive/genres_original/country/country.00060.wav
# /content/drive/MyDrive/genres_original/country/country.00050.wav
# /content/drive/MyDrive/genres_original/country/country.00057.wav
# /content/drive/MyDrive/genres_original/country/country.00063.wav
# /content/drive/MyDrive/genres_original/country/country.00079.wav
# /content/drive/MyDrive/genres_original/country/country.00074.wav
# /content/drive/MyDrive/genres_original/country/country.00078.wav
# /content/drive/MyDrive/genres_original/country/country.00072.wav
# /content/drive/MyDrive/genres_original/country/country.00071.wav
# /content/drive/MyDrive/genres_original/country/country.00066.wav
# /content/drive/MyDrive/genres_original/country/country.00077.wav
# /content/drive/MyDrive/genres_original/country/country.00067.wav
# /content/drive/MyDrive/genres_original/country/country.00073.wav
# /content/drive/MyDrive/genres_original/country/country.00065.wav
# /content/drive/MyDrive/genres_original/country/country.00075.wav
# /content/drive/MyDrive/genres_original/country/country.00068.wav
# /content/drive/MyDrive/genres_original/country/country.00070.wav
# /content/drive/MyDrive/genres_original/country/country.00064.wav
# /content/drive/MyDrive/genres_original/country/country.00069.wav
# /content/drive/MyDrive/genres_original/country/country.00083.wav
# /content/drive/MyDrive/genres_original/country/country.00094.wav
# /content/drive/MyDrive/genres_original/country/country.00087.wav
# /content/drive/MyDrive/genres_original/country/country.00091.wav
# /content/drive/MyDrive/genres_original/country/country.00082.wav
# /content/drive/MyDrive/genres_original/country/country.00089.wav
# /content/drive/MyDrive/genres_original/country/country.00081.wav
# /content/drive/MyDrive/genres_original/country/country.00090.wav
# /content/drive/MyDrive/genres_original/country/country.00085.wav
# /content/drive/MyDrive/genres_original/country/country.00092.wav
# /content/drive/MyDrive/genres_original/country/country.00088.wav
# /content/drive/MyDrive/genres_original/country/country.00093.wav
# /content/drive/MyDrive/genres_original/country/country.00084.wav
# /content/drive/MyDrive/genres_original/country/country.00080.wav
# /content/drive/MyDrive/genres_original/country/country.00086.wav
# /content/drive/MyDrive/genres_original/country/country.00097.wav
# /content/drive/MyDrive/genres_original/country/country.00096.wav
# /content/drive/MyDrive/genres_original/country/country.00095.wav
# /content/drive/MyDrive/genres_original/country/country.00099.wav
# /content/drive/MyDrive/genres_original/country/country.00098.wav
# /content/drive/MyDrive/genres_original/metal/metal.00081.wav
# /content/drive/MyDrive/genres_original/metal/metal.00082.wav
# /content/drive/MyDrive/genres_original/metal/metal.00083.wav
# /content/drive/MyDrive/genres_original/metal/metal.00084.wav
# /content/drive/MyDrive/genres_original/metal/metal.00085.wav
# /content/drive/MyDrive/genres_original/metal/metal.00086.wav
# /content/drive/MyDrive/genres_original/metal/metal.00087.wav
# /content/drive/MyDrive/genres_original/metal/metal.00088.wav
# /content/drive/MyDrive/genres_original/metal/metal.00089.wav
# /content/drive/MyDrive/genres_original/metal/metal.00090.wav
# /content/drive/MyDrive/genres_original/metal/metal.00091.wav
# /content/drive/MyDrive/genres_original/metal/metal.00092.wav
# /content/drive/MyDrive/genres_original/metal/metal.00093.wav
# /content/drive/MyDrive/genres_original/metal/metal.00094.wav
# /content/drive/MyDrive/genres_original/metal/metal.00095.wav
# /content/drive/MyDrive/genres_original/metal/metal.00096.wav
# /content/drive/MyDrive/genres_original/metal/metal.00097.wav
# /content/drive/MyDrive/genres_original/metal/metal.00098.wav
# /content/drive/MyDrive/genres_original/metal/metal.00099.wav
# /content/drive/MyDrive/genres_original/pop/pop.00000.wav
# /content/drive/MyDrive/genres_original/pop/pop.00001.wav
# /content/drive/MyDrive/genres_original/pop/pop.00002.wav
# /content/drive/MyDrive/genres_original/pop/pop.00003.wav
# /content/drive/MyDrive/genres_original/pop/pop.00004.wav
# /content/drive/MyDrive/genres_original/pop/pop.00006.wav
# /content/drive/MyDrive/genres_original/pop/pop.00005.wav
# /content/drive/MyDrive/genres_original/pop/pop.00007.wav
# /content/drive/MyDrive/genres_original/pop/pop.00008.wav
# /content/drive/MyDrive/genres_original/pop/pop.00009.wav
# /content/drive/MyDrive/genres_original/pop/pop.00010.wav
# /content/drive/MyDrive/genres_original/pop/pop.00011.wav
# /content/drive/MyDrive/genres_original/pop/pop.00012.wav
# /content/drive/MyDrive/genres_original/pop/pop.00013.wav
# /content/drive/MyDrive/genres_original/pop/pop.00014.wav
# /content/drive/MyDrive/genres_original/pop/pop.00015.wav
# /content/drive/MyDrive/genres_original/pop/pop.00016.wav
# /content/drive/MyDrive/genres_original/pop/pop.00017.wav
# /content/drive/MyDrive/genres_original/pop/pop.00018.wav
# /content/drive/MyDrive/genres_original/pop/pop.00019.wav
# /content/drive/MyDrive/genres_original/pop/pop.00021.wav
# /content/drive/MyDrive/genres_original/pop/pop.00020.wav
# /content/drive/MyDrive/genres_original/pop/pop.00022.wav
# /content/drive/MyDrive/genres_original/pop/pop.00023.wav
# /content/drive/MyDrive/genres_original/pop/pop.00024.wav
# /content/drive/MyDrive/genres_original/pop/pop.00025.wav
# /content/drive/MyDrive/genres_original/pop/pop.00026.wav
# /content/drive/MyDrive/genres_original/pop/pop.00027.wav
# /content/drive/MyDrive/genres_original/pop/pop.00028.wav
# /content/drive/MyDrive/genres_original/pop/pop.00029.wav
# /content/drive/MyDrive/genres_original/pop/pop.00030.wav
# /content/drive/MyDrive/genres_original/pop/pop.00032.wav
# /content/drive/MyDrive/genres_original/pop/pop.00031.wav
# /content/drive/MyDrive/genres_original/pop/pop.00035.wav
# /content/drive/MyDrive/genres_original/pop/pop.00034.wav
# /content/drive/MyDrive/genres_original/pop/pop.00033.wav
# /content/drive/MyDrive/genres_original/pop/pop.00037.wav
# /content/drive/MyDrive/genres_original/pop/pop.00038.wav
# /content/drive/MyDrive/genres_original/pop/pop.00039.wav
# /content/drive/MyDrive/genres_original/pop/pop.00036.wav
# /content/drive/MyDrive/genres_original/pop/pop.00040.wav
# /content/drive/MyDrive/genres_original/pop/pop.00041.wav
# /content/drive/MyDrive/genres_original/pop/pop.00042.wav
# /content/drive/MyDrive/genres_original/pop/pop.00043.wav
# /content/drive/MyDrive/genres_original/pop/pop.00046.wav
# /content/drive/MyDrive/genres_original/pop/pop.00044.wav
# /content/drive/MyDrive/genres_original/pop/pop.00045.wav
# /content/drive/MyDrive/genres_original/pop/pop.00047.wav
# /content/drive/MyDrive/genres_original/pop/pop.00048.wav
# /content/drive/MyDrive/genres_original/pop/pop.00049.wav
# /content/drive/MyDrive/genres_original/pop/pop.00050.wav
# /content/drive/MyDrive/genres_original/pop/pop.00051.wav
# /content/drive/MyDrive/genres_original/pop/pop.00052.wav
# /content/drive/MyDrive/genres_original/pop/pop.00053.wav
# /content/drive/MyDrive/genres_original/pop/pop.00054.wav
# /content/drive/MyDrive/genres_original/pop/pop.00055.wav
# /content/drive/MyDrive/genres_original/pop/pop.00056.wav
# /content/drive/MyDrive/genres_original/pop/pop.00057.wav
# /content/drive/MyDrive/genres_original/pop/pop.00058.wav
# /content/drive/MyDrive/genres_original/pop/pop.00059.wav
# /content/drive/MyDrive/genres_original/pop/pop.00060.wav
# /content/drive/MyDrive/genres_original/pop/pop.00062.wav
# /content/drive/MyDrive/genres_original/pop/pop.00061.wav
# /content/drive/MyDrive/genres_original/pop/pop.00063.wav
# /content/drive/MyDrive/genres_original/pop/pop.00064.wav
# /content/drive/MyDrive/genres_original/pop/pop.00065.wav
# /content/drive/MyDrive/genres_original/pop/pop.00066.wav
# /content/drive/MyDrive/genres_original/pop/pop.00067.wav
# /content/drive/MyDrive/genres_original/pop/pop.00068.wav
# /content/drive/MyDrive/genres_original/pop/pop.00069.wav
# /content/drive/MyDrive/genres_original/pop/pop.00070.wav
# /content/drive/MyDrive/genres_original/pop/pop.00071.wav
# /content/drive/MyDrive/genres_original/pop/pop.00072.wav
# /content/drive/MyDrive/genres_original/pop/pop.00073.wav
# /content/drive/MyDrive/genres_original/pop/pop.00074.wav
# /content/drive/MyDrive/genres_original/pop/pop.00075.wav
# /content/drive/MyDrive/genres_original/pop/pop.00076.wav
# /content/drive/MyDrive/genres_original/pop/pop.00078.wav
# /content/drive/MyDrive/genres_original/pop/pop.00077.wav
# /content/drive/MyDrive/genres_original/pop/pop.00079.wav
# /content/drive/MyDrive/genres_original/pop/pop.00081.wav
# /content/drive/MyDrive/genres_original/pop/pop.00080.wav
# /content/drive/MyDrive/genres_original/pop/pop.00082.wav
# /content/drive/MyDrive/genres_original/pop/pop.00083.wav
# /content/drive/MyDrive/genres_original/pop/pop.00084.wav
# /content/drive/MyDrive/genres_original/pop/pop.00085.wav
# /content/drive/MyDrive/genres_original/pop/pop.00086.wav
# /content/drive/MyDrive/genres_original/pop/pop.00088.wav
# /content/drive/MyDrive/genres_original/pop/pop.00087.wav
# /content/drive/MyDrive/genres_original/pop/pop.00089.wav
# /content/drive/MyDrive/genres_original/pop/pop.00090.wav
# /content/drive/MyDrive/genres_original/pop/pop.00091.wav
# /content/drive/MyDrive/genres_original/pop/pop.00092.wav
# /content/drive/MyDrive/genres_original/pop/pop.00093.wav
# /content/drive/MyDrive/genres_original/pop/pop.00094.wav
# /content/drive/MyDrive/genres_original/pop/pop.00095.wav
# /content/drive/MyDrive/genres_original/pop/pop.00096.wav
# /content/drive/MyDrive/genres_original/pop/pop.00097.wav
# /content/drive/MyDrive/genres_original/pop/pop.00098.wav
# /content/drive/MyDrive/genres_original/pop/pop.00099.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00000.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00001.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00002.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00003.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00004.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00005.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00006.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00007.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00008.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00009.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00010.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00011.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00012.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00013.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00014.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00015.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00016.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00017.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00018.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00019.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00020.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00021.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.00022.wav
# /content/drive/MyDrive/genres_original/reggae/reggae.
# /content/drive/MyDrive/genres_original/blues/blues.00041.wav
# /content/drive/MyDrive/genres_original/blues/blues.00042.wav
# /content/drive/MyDrive/genres_original/blues/blues.00045.wav
# /content/drive/MyDrive/genres_original/blues/blues.00043.wav
# /content/drive/MyDrive/genres_original/blues/blues.00044.wav
# /content/drive/MyDrive/genres_original/blues/blues.00046.wav
# /content/drive/MyDrive/genres_original/blues/blues.00047.wav
# /content/drive/MyDrive/genres_original/blues/blues.00048.wav
# /content/drive/MyDrive/genres_original/blues/blues.00049.wav
# /content/drive/MyDrive/genres_original/blues/blues.00050.wav
# /content/drive/MyDrive/genres_original/blues/blues.00052.wav
# /content/drive/MyDrive/genres_original/blues/blues.00051.wav
# /content/drive/MyDrive/genres_original/blues/blues.00053.wav
# /content/drive/MyDrive/genres_original/blues/blues.00055.wav
# /content/drive/MyDrive/genres_original/blues/blues.00054.wav
# /content/drive/MyDrive/genres_original/blues/blues.00056.wav
# /content/drive/MyDrive/genres_original/blues/blues.00057.wav
# /content/drive/MyDrive/genres_original/blues/blues.00058.wav
# /content/drive/MyDrive/genres_original/blues/blues.00059.wav
# /content/drive/MyDrive/genres_original/blues/blues.00060.wav
# /content/drive/MyDrive/genres_original/blues/blues.00061.wav
# /content/drive/MyDrive/genres_original/blues/blues.00063.wav
# /content/drive/MyDrive/genres_original/blues/blues.00064.wav
# /content/drive/MyDrive/genres_original/blues/blues.00062.wav
# /content/drive/MyDrive/genres_original/blues/blues.00067.wav
# /content/drive/MyDrive/genres_original/blues/blues.00065.wav
# /content/drive/MyDrive/genres_original/blues/blues.00066.wav
# /content/drive/MyDrive/genres_original/blues/blues.00068.wav
# /content/drive/MyDrive/genres_original/blues/blues.00069.wav
# /content/drive/MyDrive/genres_original/blues/blues.00070.wav
# /content/drive/MyDrive/genres_original/blues/blues.00071.wav
# /content/drive/MyDrive/genres_original/blues/blues.00072.wav
# /content/drive/MyDrive/genres_original/blues/blues.00073.wav
# /content/drive/MyDrive/genres_original/blues/blues.00077.wav
# /content/drive/MyDrive/genres_original/blues/blues.00074.wav
# /content/drive/MyDrive/genres_original/blues/blues.00078.wav
# /content/drive/MyDrive/genres_original/blues/blues.00079.wav
# /content/drive/MyDrive/genres_original/blues/blues.00076.wav
# /content/drive/MyDrive/genres_original/blues/blues.00075.wav
# /content/drive/MyDrive/genres_original/blues/blues.00080.wav
# /content/drive/MyDrive/genres_original/blues/blues.00081.wav
# /content/drive/MyDrive/genres_original/blues/blues.00082.wav
# /content/drive/MyDrive/genres_original/blues/blues.00083.wav
# /content/drive/MyDrive/genres_original/blues/blues.00084.wav
# /content/drive/MyDrive/genres_original/blues/blues.00085.wav
# /content/drive/MyDrive/genres_original/blues/blues.00086.wav
# /content/drive/MyDrive/genres_original/blues/blues.00087.wav
# /content/drive/MyDrive/genres_original/blues/blues.00088.wav
# /content/drive/MyDrive/genres_original/blues/blues.00089.wav
# /content/drive/MyDrive/genres_original/blues/blues.00090.wav
# /content/drive/MyDrive/genres_original/blues/blues.00091.wav
# /content/drive/MyDrive/genres_original/blues/blues.00093.wav
# /content/drive/MyDrive/genres_original/blues/blues.00092.wav
# /content/drive/MyDrive/genres_original/blues/blues.00094.wav
# /content/drive/MyDrive/genres_original/blues/blues.00095.wav
# /content/drive/MyDrive/genres_original/blues/blues.00096.wav
# /content/drive/MyDrive/genres_original/blues/blues.00097.wav
# /content/drive/MyDrive/genres_original/blues/blues.00098.wav
# /content/drive/MyDrive/genres_original/blues/blues.00099.wav

# %%
epochs = 100
batch_size = 32
sample_interval = 1
latent_dim = 100

# %%
import os
import numpy as np
from scipy.io import wavfile

# Audio Config
DURATION = 3
SAMPLE_RATE = 6000
AUDIO_SHAPE = SAMPLE_RATE * DURATION

# Paths
DATASET_PATH = "/content/drive/MyDrive/genres_original/classical"  # Replace this with the path to your dataset directory

# Load train data
def load_train_data(label=None, input_length=AUDIO_SHAPE):
    train_files = os.listdir(DATASET_PATH)
    cur_batch_size = len(train_files)
    X = np.empty((cur_batch_size, input_length))
    for i, train_fname in enumerate(train_files):
        file_path = os.path.join(DATASET_PATH, train_fname)

        # Read and Resample the audio
        _, data = wavfile.read(file_path)
        if len(data) != input_length:
            data = np.interp(np.linspace(0, len(data) - 1, input_length), np.arange(len(data)), data)

        X[i,] = data
    print("Data Loaded...")
    return X

# Standardize Data
def normalization(X):
    mean = X.mean(axis=0, keepdims=True)
    std = X.std(axis=0, keepdims=True)
    X = (X - mean) / std
    print("Data Normalized...")
    return X

# Rescale Data to be in range [rangeMin, rangeMax]
def rescale(X, rangeMin=-1, rangeMax=+1):
    maxi = X.max()
    mini = X.min()
    X = np.interp(X, (mini, maxi), (rangeMin, rangeMax))  # This is just min-max scaling
    print("Data Rescaled...")
    return X

if __name__ == "__main__":
    # Example usage:
    # Load all data from the "classical" directory
    train_data = normalization(load_train_data(input_length=AUDIO_SHAPE))
# Out:
# Data Loaded...
# Data Normalized...

# %%
train_data = normalization(load_train_data(AUDIO_SHAPE))
# Out:
# Data Loaded...
# Data Normalized...

# %%
x_train = rescale(train_data)
# Out:
# Data Rescaled...

# %%
audio_samples = [x_train[0], x_train[2], x_train[10], x_train[20], x_train[42]]

for audio in audio_samples:
        IPython.display.display(ipd.Audio(data = audio, rate = SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
length_of_audio_samples = len(audio_samples)
fig, ax = plt.subplots(int(length_of_audio_samples/2),2, figsize = (16,length_of_audio_samples*3))

# drwing plots
count = 0
for r in range(0,int(length_of_audio_samples/2)):
    for c in range(0,2):
        sample = audio_samples[count]
        ax[r,c].plot(sample)
        count += 1
        ax[r,c].set_xlabel("Samples")

fig.suptitle("Samples", fontsize = 17)
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam

# Define the generator
def build_generator(latent_dim, audio_shape):
    model = models.Sequential()
    model.add(layers.Dense(256, input_dim=latent_dim))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(1024))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(2048))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(4096))  # Adjusted to be a power of 2
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.BatchNormalization(momentum=0.8))
    model.add(layers.Dense(audio_shape, activation='tanh'))  # Output layer
    return model

# Example usage:
latent_dim = 100  # Dimensionality of the latent space (input)
audio_shape = 18000  # For example, to generate 3 seconds of audio at a sample rate of 6kHz
generator = build_generator(latent_dim, audio_shape)

# Compile the generator
generator.compile(loss="binary_crossentropy", optimizer=Adam(lr=0.0001, beta_1=0.5))

# Check the generator's architecture
generator.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               25856
#
#  leaky_re_lu (LeakyReLU)     (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1024)              0
#
#  batch_normalization_2 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense_3 (Dense)             (None, 2048)              2099200
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 2048)              0
#
#  batch_normalization_3 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_4 (Dense)             (None, 4096)              8392704
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 4096)              0
#
#  batch_normalization_4 (Bat  (None, 4096)              16384
#  chNormalization)
#
#  dense_5 (Dense)             (None, 18000)             73746000
#
# =================================================================
# Total params: 84952400 (324.07 MB)
# Trainable params: 84936528 (324.01 MB)
# Non-trainable params: 15872 (62.00 KB)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Define the discriminator
def build_discriminator(audio_shape):
    model = models.Sequential()
    model.add(layers.Input(shape=(audio_shape,)))
    model.add(layers.Dense(4096))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(2048))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(1024))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(512))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(256))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dense(128))
    model.add(layers.LeakyReLU(alpha=0.2))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(1, activation='sigmoid'))

    return model

# Example usage:
audio_shape = 18000  # Assuming the same audio shape as your generator
discriminator = build_discriminator(audio_shape)

# Compile the discriminator
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5), metrics=['accuracy'])

# Check the discriminator's architecture
discriminator.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 4096)              73732096
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 4096)              0
#
#  dense_7 (Dense)             (None, 2048)              8390656
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 2048)              0
#
#  dense_8 (Dense)             (None, 1024)              2098176
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 1024)              0
#
#  dense_9 (Dense)             (None, 512)               524800
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 512)               0
#
#  dense_10 (Dense)            (None, 256)               131328
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 256)               0
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_12 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 84910081 (323.91 MB)
# Trainable params: 84910081 (323.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define the dimensions
latent_dim = 100  # Dimensionality of the latent space
AUDIO_SHAPE = 18000  # This should be defined somewhere in your script as the shape of the audio

# Build and compile the discriminator
discriminator = build_discriminator(audio_shape=AUDIO_SHAPE)  # Corrected parameter name
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Build the generator
generator = build_generator(latent_dim, audio_shape)

# Define the combined GAN model
def build_gan(generator, discriminator):
    # Make the discriminator not trainable when we are training the generator
    discriminator.trainable = False
    model = models.Sequential()
    model.add(generator)  # Add the generator
    model.add(discriminator)  # Add the discriminator
    return model

# Build and compile the GAN model
gan = build_gan(generator, discriminator)
gan.compile(loss='binary_crossentropy', optimizer='adam')

# Print model summaries
print("Generator Summary:")
generator.summary()
print("\nDiscriminator Summary:")
discriminator.summary()
print("\nGAN Summary:")
gan.summary()
# Out:
# Generator Summary:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 256)               25856
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 256)               0
#
#  batch_normalization_5 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_21 (Dense)            (None, 512)               131584
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 512)               0
#
#  batch_normalization_6 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_22 (Dense)            (None, 1024)              525312
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 1024)              0
#
#  batch_normalization_7 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dense_23 (Dense)            (None, 2048)              2099200
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 2048)              0
#
#  batch_normalization_8 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_24 (Dense)            (None, 4096)              8392704
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 4096)              0
#
#  batch_normalization_9 (Bat  (None, 4096)              16384
#  chNormalization)
#
#  dense_25 (Dense)            (None, 18000)             73746000
#
# =================================================================
# Total params: 84952400 (324.07 MB)
# Trainable params: 84936528 (324.01 MB)
# Non-trainable params: 15872 (62.00 KB)
# _________________________________________________________________
#
# Discriminator Summary:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 4096)              73732096
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 4096)              0
#
#  dense_14 (Dense)            (None, 2048)              8390656
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 2048)              0
#
#  dense_15 (Dense)            (None, 1024)              2098176
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 1024)              0
#
#  dense_16 (Dense)            (None, 512)               524800
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 512)               0
#
#  dense_17 (Dense)            (None, 256)               131328
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 256)               0
#
#  dense_18 (Dense)            (None, 128)               32896
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_19 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 84910081 (323.91 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 84910081 (323.91 MB)
# _________________________________________________________________
#
# GAN Summary:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_3 (Sequential)   (None, 18000)             84952400
#
#  sequential_2 (Sequential)   (None, 1)                 84910081
#
# =================================================================
# Total params: 169862481 (647.97 MB)
# Trainable params: 84936528 (324.01 MB)
# Non-trainable params: 84925953 (323.97 MB)
# _________________________________________________________________

# %%
def create_gan(discriminator, generator):
    discriminator.trainable = False
    gan_input = Input(shape=(100,))
    x = generator(gan_input)
    gan_output = discriminator(x)  # discriminator(generator(Input(100,)))
    gan = Model(inputs = gan_input, outputs = gan_output)
    gan.compile(loss = "binary_crossentropy", optimizer = "adam")
    return gan

gan = create_gan(discriminator, generator)
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 100)]             0
#
#  sequential_3 (Sequential)   (None, 18000)             84952400
#
#  sequential_2 (Sequential)   (None, 1)                 84910081
#
# =================================================================
# Total params: 169862481 (647.97 MB)
# Trainable params: 84936528 (324.01 MB)
# Non-trainable params: 84925953 (323.97 MB)
# _________________________________________________________________

# %%
def show_gen_samples(epochs, samples = 3):
    samplePlot = []
    fig        = plt.figure(figsize = (1, samples))
    noise      = np.random.normal(0, 1, (samples,100))
    audios     = g.predict(noise)
    for i, audio in enumerate(audios):
        IPython.display.display(ipd.Audio(data = audio, rate = SAMPLE_RATE))
        samplePlot.append(fig.add_subplot(1, samples, i+1))
        samplePlot[i].plot(audio.flatten(), '-', )  # remove this section and do not display audio at every step.
    plt.gcf().set_size_inches(25, 5)
    plt.subplots_adjust(wspace=0.3,hspace=0.3)
    fig.suptitle("{} Epochs Result".format(epochs), fontsize = 17)
    plt.show()

# %%
# Define a function to train the GAN and return loss values
def train_gan(generator, discriminator, gan, train_data, epochs, batch_size, sample_interval):
    # Reshape the data for training
    train_data = train_data.reshape(train_data.shape[0], -1)

    # Adversarial ground truths
    valid = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    # Lists to store loss values for plotting
    d_loss_list = []
    g_loss_list = []

    for epoch in range(epochs):
        # ---------------------
        #  Train Discriminator
        # ---------------------

        # Select a random batch of real audio samples
        idx = np.random.randint(0, train_data.shape[0], batch_size)
        real_samples = train_data[idx]

        # Generate a batch of fake audio samples
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        gen_samples = generator.predict(noise)

        # Train the discriminator
        d_loss_real = discriminator.train_on_batch(real_samples, valid)
        d_loss_fake = discriminator.train_on_batch(gen_samples, fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # ---------------------
        #  Train Generator
        # ---------------------

        # Generate a batch of noise vectors
        noise = np.random.normal(0, 1, (batch_size, latent_dim))

        # Train the generator (to have the discriminator label samples as valid)
        g_loss = gan.train_on_batch(noise, valid)

        # Save loss values for plotting
        d_loss_list.append(d_loss[0])
        g_loss_list.append(g_loss)

    # Return the loss values
    return d_loss_list, g_loss_list

# Train the GAN and get loss values
d_loss_values, g_loss_values = train_gan(generator, discriminator, gan, train_data, epochs, batch_size, sample_interval)

# Plot the generator and discriminator loss values
plt.plot(range(epochs), d_loss_values, label="Discriminator loss")
plt.plot(range(epochs), g_loss_values, label="Generator loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Generator and Discriminator Loss over Epochs")
plt.show()
# Out:
# 1/1 [==============================] - 1s 771ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 278ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 145ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio

# Define a function to generate and play audio samples
def generate_and_play_samples(generator, num_samples=3, latent_dim=100, sample_length=6000):
    # Generate random noise as input to the generator
    noise = np.random.normal(0, 1, (num_samples, latent_dim))
    # Generate audio samples using the generator
    gen_samples = generator.predict(noise)

    # Play each generated audio sample
    for i in range(num_samples):
        # Convert audio sample to a playable format
        audio_sample = gen_samples[i].reshape(-1)
        # Play the audio sample
        display(Audio(audio_sample, rate=6000))

# Generate and play audio samples
generate_and_play_samples(generator)
# Out:
# 1/1 [==============================] - 0s 330ms/step
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
